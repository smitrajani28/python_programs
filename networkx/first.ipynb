# %%
import networkx as nx

# %%
g= nx.Graph()
g.add_edge('a','b')
g.add_edge('c','b')
g.add_edge('c','d')
g.add_edge('d','e')
g.add_edge('e','f')
g.add_edge('f','g')
g.add_edge('g','h')
nx.draw(g,with_labels=True)
