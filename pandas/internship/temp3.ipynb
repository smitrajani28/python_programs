# %%
import pandas as pd
import openpyxl
from itertools import product

def get_cell_color(cell):
    if cell.fill.start_color.index != '00000000':
        return cell.fill.start_color.index
    return None

def get_values(value, color, column, style=None):
    if value is not None:
        all_values[headers[idx]].update([value])
    if value == None:
        if column == 'CENTER STONE':
            if color == 'FF00FF00':  # Green
                # print("green")
                return ['Moissanite', 'Lab Diamond', 'Natural Diamond', 'Natural Champagne Diamond',
                        'Natural Cornflower Blue Sapphire', 'Natural Emerald', 'Natural Ruby']
            elif color == 'FFFFFF00':  # Yellow
                # print("yellow")
                return ['Moissanite', 'Lab Diamond', 'Natural Diamond']
        elif column == 'BAND STYLE':
            if color == 'FFFF9900':  # Orange
                # print("orange")
                return ['Pave Diamond Sides', 'Plain Band']
        elif column == 'PROFILE':
            if color == 'FF00FFFF':  # Sky Blue
                # print("blue")
                return ['*Only Raised']
            elif color == 'FFFF00FF':  # Purple
                # print("purple")
                return ['*Only Inline']
            return [value] if value else []
    return [value] if value else []

# Read the Excel file
file_path = 'Copy of Berlinger x Gemist - Product Sheet V1 -PARTNER.xlsx'
wb = openpyxl.load_workbook(file_path)
sheet = wb.active

# Get headers
headers = ['SETTING', 'STYLE', 'METAL', 'CENTER STONE', 'BAND STYLE', 'PROFILE']

# Read data and organize by SETTING
settings_data = {}
all_values = {header: set() for header in headers[1:]}

print("Reading data from Excel:")
current_setting = None
for row in sheet.iter_rows(min_row=2, max_col=len(headers), values_only=False):
    setting = row[1].value
    if setting:
        current_setting = setting
        if current_setting not in settings_data:
            settings_data[current_setting] = {header: set() for header in headers[1:]}
        print(f"New setting found: {current_setting}")
    
    if current_setting:
        for idx, cell in enumerate(row[1:], 1):
            value = cell.value
            color = get_cell_color(cell)
                
            if value or color:
                values = get_values(value, color, headers[idx])
                settings_data[current_setting][headers[idx]].update(values)
                print(f"  {headers[idx]}: {values}")


print("\nData collected:")
for setting, data in settings_data.items():
    print(f"Setting: {setting}")
    for header, values in data.items():
        print(f"  {header}: {values}")

# Generate combinations
all_combinations = []

print("\nGenerating combinations:")
for setting, data in settings_data.items():
    profiles = list(data['PROFILE'])
    if not profiles:
        profiles = all_values['PROFILE']

    if any(c == 'FF00FFFF' for c in profiles):  # If there's a sky blue color
        profiles = ['*Only Raised']
    elif any(c == 'FFFF00FF' for c in profiles):  # If there's a purple color
        profiles = ['*Only Inline']
    else:
        profiles = list(set(profiles) | set(all_values['PROFILE']))

    setting_combinations = list(product(
        [setting],
        data['STYLE'] or all_values['STYLE'],
        data['METAL'] or all_values['METAL'],
        data['CENTER STONE'] or all_values['CENTER STONE'],
        data['BAND STYLE'] or all_values['BAND STYLE'],
        profiles
    ))
    all_combinations.extend(setting_combinations)
    print(f"Combinations for {setting}: {len(setting_combinations)}")

# Create DataFrame
combinations_df = pd.DataFrame(all_combinations, columns=headers)

# Remove rows where all columns except SETTING are empty
combinations_df = combinations_df.loc[combinations_df.iloc[:, 1:].any(axis=1)]

# Save to Excel
output_file_path = 'Combinations_Result_Final7.xlsx'
combinations_df.to_excel(output_file_path, index=False)

print(f"\nTotal combinations generated: {len(combinations_df)}")
print(f"Combinations saved to {output_file_path}")
# Out:
# Reading data from Excel:
# New setting found: Oval Ballerina Round Center 1.00 ctw.
#   STYLE: ['Oval Ballerina Round Center 1.00 ctw.']
#   METAL: ['14K Yellow Gold']
#   CENTER STONE: ['Moissanite']
#   BAND STYLE: ['Antique Shape Diamond Sides']
#   PROFILE: ['Inline']
# New setting found: Oval Ballerina Round Center 0.35 ctw
#   STYLE: ['Oval Ballerina Round Center 0.35 ctw']
#   METAL: ['14K White Gold']
#   CENTER STONE: ['Lab Diamond']
#   BAND STYLE: ['Pave Diamond Sides ']
#   PROFILE: ['Raised']
# New setting found: Oval Ballerina Oval Center
#   STYLE: ['Oval Ballerina Oval Center']
#   METAL: ['14K Rose Gold']
#   CENTER STONE: ['Natural Diamond']
#   BAND STYLE: ['Plain Band']
# New setting found: Round with Feather Marquise
#   STYLE: ['Round with Feather Marquise']
#   METAL: ['18K Yellow Gold']
#   CENTER STONE: ['Natural Champagne Diamond']
# New setting found: Round with Marquise
#   STYLE: ['Round with Marquise']
#   METAL: ['18K White Gold']
#   CENTER STONE: ['Natural Cornflower Blue Sapphire']
# New setting found: Sunflower
#   STYLE: ['Sunflower']
#   METAL: ['18K Rose Gold']
#   CENTER STONE: ['Natural Emerald']
# New setting found: Flora
#   STYLE: ['Flora']
#   METAL: ['Platinum']
#   CENTER STONE: ['Natural Ruby']
#   BAND STYLE: ['Pave Diamond Sides', 'Plain Band']
# New setting found: Bella
#   STYLE: ['Bella']
#   CENTER STONE: ['Natural Aquamarine']
# New setting found: Emerald Ballerina
#   STYLE: ['Emerald Ballerina']
#   CENTER STONE: ['Natural Morganite']
# New setting found: Oval with Carré
#   STYLE: ['Oval with Carré']
# New setting found: Not So Mini French Cut Halo
#   STYLE: ['Not So Mini French Cut Halo']
#   PROFILE: ['*Only Raised']
# New setting found: French Cut Halo
#   STYLE: ['French Cut Halo']
#   PROFILE: ['*Only Raised']
# New setting found: Ballerina Round
#   STYLE: ['Ballerina Round']
# New setting found: Ballerina Round with Halo
#   STYLE: ['Ballerina Round with Halo']
# New setting found: Pear & Baguette Round with Halo
#   STYLE: ['Pear & Baguette Round with Halo']
# New setting found: Sunflower Round
#   STYLE: ['Sunflower Round']
# New setting found: Marquise Ballerina
#   STYLE: ['Marquise Ballerina']
# New setting found: Pear Mosaic
#   STYLE: ['Pear Mosaic']
# New setting found: Mini Kite Oval
#   STYLE: ['Mini Kite Oval']
# New setting found: Mini Kite Round
#   STYLE: ['Mini Kite Round']
# New setting found: Diamond Shape Halo Oval
#   STYLE: ['Diamond Shape Halo Oval']
# New setting found: Diamond Shape Halo Round
#   STYLE: ['Diamond Shape Halo Round']
# New setting found: Round Halo
#   STYLE: ['Round Halo']
# New setting found: Ballerina Round
#   STYLE: ['Ballerina Round']
# New setting found: Ballerina Elongated Emerald
#   STYLE: ['Ballerina Elongated Emerald']
#   BAND STYLE: ['Pave Diamond Sides ']
#   PROFILE: ['*Only Raised']
# New setting found: Square Deco with 8x6 Emerald
#   STYLE: ['Square Deco with 8x6 Emerald']
#   BAND STYLE: ['Plain Band']
#   PROFILE: ['*Only Raised']
# New setting found: Square Deco with 6x4 Emerald
#   STYLE: ['Square Deco with 6x4 Emerald']
#   PROFILE: ['*Only Raised']
# New setting found: Pear Deco with 8x6 Emerald
#   STYLE: ['Pear Deco with 8x6 Emerald']
#   PROFILE: ['*Only Raised']
# New setting found: Pear Deco with 6x4 Emerald
#   STYLE: ['Pear Deco with 6x4 Emerald']
#   METAL: []
#   CENTER STONE: ['Moissanite', 'Lab Diamond', 'Natural Diamond', 'Natural Champagne Diamond', 'Natural Cornflower Blue Sapphire', 'Natural Emerald', 'Natural Ruby']
# New setting found: Square Deco with Asscher
#   STYLE: ['Square Deco with Asscher']
# New setting found: Square Deco with Round
#   STYLE: ['Square Deco with Round']
# New setting found: Rockeffeller
#   STYLE: ['Rockeffeller']
# New setting found: Empire
#   STYLE: ['Empire']
#   BAND STYLE: ['Plain Band']
# New setting found: Nouveau
#   STYLE: ['Nouveau']
#   PROFILE: ['*Only Inline']
# New setting found: Rose Cut Oval with Marquise
#   STYLE: ['Rose Cut Oval with Marquise']
#   PROFILE: ['*Only Inline']
# New setting found: Brilliant Cut Oval with Marquise
#   STYLE: ['Brilliant Cut Oval with Marquise']
#   PROFILE: ['*Only Inline']
# New setting found: Oval with Baguette & Pear
#   STYLE: ['Oval with Baguette & Pear']
#   PROFILE: ['*Only Raised']
# New setting found: Emerald and Trillion
#   STYLE: ['Emerald and Trillion']
#   PROFILE: ['*Only Inline']
# New setting found: Oval and Pear
#   STYLE: ['Oval and Pear']
#   PROFILE: ['*Only Raised']
# New setting found: Confetti
#   STYLE: ['Confetti']
#   CENTER STONE: ['Moissanite', 'Lab Diamond', 'Natural Diamond']
#   PROFILE: ['*Only Raised']
# New setting found: Peacock
#   STYLE: ['Peacock']
#
# Data collected:
# Setting: Oval Ballerina Round Center 1.00 ctw.
#   STYLE: {'Oval Ballerina Round Center 1.00 ctw.'}
#   METAL: {'14K Yellow Gold'}
#   CENTER STONE: {'Moissanite'}
#   BAND STYLE: {'Antique Shape Diamond Sides'}
#   PROFILE: {'Inline'}
# Setting: Oval Ballerina Round Center 0.35 ctw
#   STYLE: {'Oval Ballerina Round Center 0.35 ctw'}
#   METAL: {'14K White Gold'}
#   CENTER STONE: {'Lab Diamond'}
#   BAND STYLE: {'Pave Diamond Sides '}
#   PROFILE: {'Raised'}
# Setting: Oval Ballerina Oval Center
#   STYLE: {'Oval Ballerina Oval Center'}
#   METAL: {'14K Rose Gold'}
#   CENTER STONE: {'Natural Diamond'}
#   BAND STYLE: {'Plain Band'}
#   PROFILE: set()
# Setting: Round with Feather Marquise
#   STYLE: {'Round with Feather Marquise'}
#   METAL: {'18K Yellow Gold'}
#   CENTER STONE: {'Natural Champagne Diamond'}
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Round with Marquise
#   STYLE: {'Round with Marquise'}
#   METAL: {'18K White Gold'}
#   CENTER STONE: {'Natural Cornflower Blue Sapphire'}
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Sunflower
#   STYLE: {'Sunflower'}
#   METAL: {'18K Rose Gold'}
#   CENTER STONE: {'Natural Emerald'}
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Flora
#   STYLE: {'Flora'}
#   METAL: {'Platinum'}
#   CENTER STONE: {'Natural Ruby'}
#   BAND STYLE: {'Pave Diamond Sides', 'Plain Band'}
#   PROFILE: set()
# Setting: Bella
#   STYLE: {'Bella'}
#   METAL: set()
#   CENTER STONE: {'Natural Aquamarine'}
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Emerald Ballerina
#   STYLE: {'Emerald Ballerina'}
#   METAL: set()
#   CENTER STONE: {'Natural Morganite'}
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Oval with Carré
#   STYLE: {'Oval with Carré'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Not So Mini French Cut Halo
#   STYLE: {'Not So Mini French Cut Halo'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Raised'}
# Setting: French Cut Halo
#   STYLE: {'French Cut Halo'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Raised'}
# Setting: Ballerina Round
#   STYLE: {'Ballerina Round'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Ballerina Round with Halo
#   STYLE: {'Ballerina Round with Halo'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Pear & Baguette Round with Halo
#   STYLE: {'Pear & Baguette Round with Halo'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Sunflower Round
#   STYLE: {'Sunflower Round'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Marquise Ballerina
#   STYLE: {'Marquise Ballerina'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Pear Mosaic
#   STYLE: {'Pear Mosaic'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Mini Kite Oval
#   STYLE: {'Mini Kite Oval'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Mini Kite Round
#   STYLE: {'Mini Kite Round'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Diamond Shape Halo Oval
#   STYLE: {'Diamond Shape Halo Oval'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Diamond Shape Halo Round
#   STYLE: {'Diamond Shape Halo Round'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Round Halo
#   STYLE: {'Round Halo'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Ballerina Elongated Emerald
#   STYLE: {'Ballerina Elongated Emerald'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: {'Pave Diamond Sides '}
#   PROFILE: {'*Only Raised'}
# Setting: Square Deco with 8x6 Emerald
#   STYLE: {'Square Deco with 8x6 Emerald'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: {'Plain Band'}
#   PROFILE: {'*Only Raised'}
# Setting: Square Deco with 6x4 Emerald
#   STYLE: {'Square Deco with 6x4 Emerald'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Raised'}
# Setting: Pear Deco with 8x6 Emerald
#   STYLE: {'Pear Deco with 8x6 Emerald'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Raised'}
# Setting: Pear Deco with 6x4 Emerald
#   STYLE: {'Pear Deco with 6x4 Emerald'}
#   METAL: set()
#   CENTER STONE: {'Natural Cornflower Blue Sapphire', 'Lab Diamond', 'Natural Ruby', 'Natural Champagne Diamond', 'Natural Diamond', 'Moissanite', 'Natural Emerald'}
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Square Deco with Asscher
#   STYLE: {'Square Deco with Asscher'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Square Deco with Round
#   STYLE: {'Square Deco with Round'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Rockeffeller
#   STYLE: {'Rockeffeller'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
# Setting: Empire
#   STYLE: {'Empire'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: {'Plain Band'}
#   PROFILE: set()
# Setting: Nouveau
#   STYLE: {'Nouveau'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Inline'}
# Setting: Rose Cut Oval with Marquise
#   STYLE: {'Rose Cut Oval with Marquise'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Inline'}
# Setting: Brilliant Cut Oval with Marquise
#   STYLE: {'Brilliant Cut Oval with Marquise'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Inline'}
# Setting: Oval with Baguette & Pear
#   STYLE: {'Oval with Baguette & Pear'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Raised'}
# Setting: Emerald and Trillion
#   STYLE: {'Emerald and Trillion'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Inline'}
# Setting: Oval and Pear
#   STYLE: {'Oval and Pear'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: {'*Only Raised'}
# Setting: Confetti
#   STYLE: {'Confetti'}
#   METAL: set()
#   CENTER STONE: {'Lab Diamond', 'Natural Diamond', 'Moissanite'}
#   BAND STYLE: set()
#   PROFILE: {'*Only Raised'}
# Setting: Peacock
#   STYLE: {'Peacock'}
#   METAL: set()
#   CENTER STONE: set()
#   BAND STYLE: set()
#   PROFILE: set()
#
# Generating combinations:
# Combinations for Oval Ballerina Round Center 1.00 ctw.: 2
# Combinations for Oval Ballerina Round Center 0.35 ctw: 2
# Combinations for Oval Ballerina Oval Center: 2
# Combinations for Round with Feather Marquise: 6
# Combinations for Round with Marquise: 6
# Combinations for Sunflower: 6
# Combinations for Flora: 4
# Combinations for Bella: 42
# Combinations for Emerald Ballerina: 42
# Combinations for Oval with Carré: 378
# Combinations for Not So Mini French Cut Halo: 567
# Combinations for French Cut Halo: 567
# Combinations for Ballerina Round: 378
# Combinations for Ballerina Round with Halo: 378
# Combinations for Pear & Baguette Round with Halo: 378
# Combinations for Sunflower Round: 378
# Combinations for Marquise Ballerina: 378
# Combinations for Pear Mosaic: 378
# Combinations for Mini Kite Oval: 378
# Combinations for Mini Kite Round: 378
# Combinations for Diamond Shape Halo Oval: 378
# Combinations for Diamond Shape Halo Round: 378
# Combinations for Round Halo: 378
# Combinations for Ballerina Elongated Emerald: 189
# Combinations for Square Deco with 8x6 Emerald: 189
# Combinations for Square Deco with 6x4 Emerald: 567
# Combinations for Pear Deco with 8x6 Emerald: 567
# Combinations for Pear Deco with 6x4 Emerald: 294
# Combinations for Square Deco with Asscher: 378
# Combinations for Square Deco with Round: 378
# Combinations for Rockeffeller: 378
# Combinations for Empire: 126
# Combinations for Nouveau: 567
# Combinations for Rose Cut Oval with Marquise: 567
# Combinations for Brilliant Cut Oval with Marquise: 567
# Combinations for Oval with Baguette & Pear: 567
# Combinations for Emerald and Trillion: 567
# Combinations for Oval and Pear: 567
# Combinations for Confetti: 189
# Combinations for Peacock: 378
#
# Total combinations generated: 12817
# Combinations saved to Combinations_Result_Final7.xlsx

# %%
pd.DataFrame(settings_data)
# Out:
#                                                            Oval  \
# STYLE         {Sunflower, Round with Feather Marquise, Flora...
# METAL         {Platinum, 14K Rose Gold, 18K Rose Gold, 14K Y...
# CENTER STONE  {Natural Cornflower Blue Sapphire, Lab Diamond...
# BAND STYLE    {Pave Diamond Sides , Pave Diamond Sides, Plai...
# PROFILE                                        {Raised, Inline}
#
#                                                         Emerald  \
# STYLE         {Oval with Carré, Not So Mini French Cut Halo,...
# METAL                                                        {}
# CENTER STONE                                {Natural Morganite}
# BAND STYLE                                                   {}
# PROFILE                                          {*Only Raised}
#
#                                                           Round  \
# STYLE         {Ballerina Round with Halo, Sunflower Round, P...
# METAL                                                        {}
# CENTER STONE                                                 {}
# BAND STYLE                                                   {}
# PROFILE                                                      {}
#
#                           Marquise           Pear  \
# STYLE         {Marquise Ballerina}  {Pear Mosaic}
# METAL                           {}             {}
# CENTER STONE                    {}             {}
# BAND STYLE                      {}             {}
# PROFILE                         {}             {}
#
#                                                            Kite  \
# STYLE         {Mini Kite Round, Mini Kite Oval, Diamond Shap...
# METAL                                                        {}
# CENTER STONE                                                 {}
# BAND STYLE                                                   {}
# PROFILE                                                      {}
#
#                                                         Hexagon  \
# STYLE         {Ballerina Elongated Emerald, Round Halo, Ball...
# METAL                                                        {}
# CENTER STONE                                                 {}
# BAND STYLE                                {Pave Diamond Sides }
# PROFILE                                          {*Only Raised}
#
#                                                            Deco  \
# STYLE         {Square Deco with Round, Square Deco with 8x6 ...
# METAL                                                        {}
# CENTER STONE  {Natural Cornflower Blue Sapphire, Lab Diamond...
# BAND STYLE                                         {Plain Band}
# PROFILE                                          {*Only Raised}
#
#                          Rockefeller  \
# STYLE         {Empire, Rockeffeller}
# METAL                             {}
# CENTER STONE                      {}
# BAND STYLE              {Plain Band}
# PROFILE                           {}
#
#                                                     Three Stone
# STYLE         {Rose Cut Oval with Marquise, Oval with Baguet...
# METAL                                                        {}
# CENTER STONE         {Lab Diamond, Natural Diamond, Moissanite}
# BAND STYLE                                                   {}
# PROFILE                            {*Only Inline, *Only Raised}
